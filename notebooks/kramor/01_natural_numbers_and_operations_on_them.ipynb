# %% [markdown]
# # Natural numbers and operations on them

# %% [markdown]
# 1. Prove that one of two consecutive even numbers is divisible by 4.

# %%
evens = list(range(2, 101, 2))

# пары подряд идущих четных 
pairs = list(zip(evens[:-1], evens[1:]))

# проверка пары
for a, b in pairs:
    div_a = (a % 4 == 0)
    div_b = (b % 4 == 0)

    assert div_a != div_b, f'Ошибка на паре {a}, {b}.'

    winner = a if div_a else b
    print(f"в паре ({a:2}, {b:2}) на 4 делится число {winner}")

print('проверка пройдена')
# Out:
# Пара ( 2,  4) -> на 4 делится число 4
# Пара ( 4,  6) -> на 4 делится число 4
# Пара ( 6,  8) -> на 4 делится число 8
# Пара ( 8, 10) -> на 4 делится число 8
# Пара (10, 12) -> на 4 делится число 12
# Пара (12, 14) -> на 4 делится число 12
# Пара (14, 16) -> на 4 делится число 16
# Пара (16, 18) -> на 4 делится число 16
# Пара (18, 20) -> на 4 делится число 20
# Пара (20, 22) -> на 4 делится число 20
# Пара (22, 24) -> на 4 делится число 24
# Пара (24, 26) -> на 4 делится число 24
# Пара (26, 28) -> на 4 делится число 28
# Пара (28, 30) -> на 4 делится число 28
# Пара (30, 32) -> на 4 делится число 32
# Пара (32, 34) -> на 4 делится число 32
# Пара (34, 36) -> на 4 делится число 36
# Пара (36, 38) -> на 4 делится число 36
# Пара (38, 40) -> на 4 делится число 40
# Пара (40, 42) -> на 4 делится число 40
# Пара (42, 44) -> на 4 делится число 44
# Пара (44, 46) -> на 4 делится число 44
# Пара (46, 48) -> на 4 делится число 48
# Пара (48, 50) -> на 4 делится число 48
# ...
