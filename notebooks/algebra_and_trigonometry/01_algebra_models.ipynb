# %% [markdown]
# 2. A mountain climber uses the model `T = 20 - 10h` to estimate the temperature T (in C) at elevation h (in kilometers, km).
# - Make a table that gives the temperature for each 1-km change in elevation, from elevation 0 km to elevation 5 km. How does temperature change as elevation ­increases?

# %%
for h in range(0, 6):
    temp = 20 - 10 * h
    print(f'{h}km = {temp}c')
# Out:
# 0km = 20c
# 1km = 10c
# 2km = 0c
# 3km = -10c
# 4km = -20c
# 5km = -30c

# %%
import pandas as pd

df = pd.DataFrame({'Elevation (km)': range(0, 6)})

df['Temperature (°C)'] = 20 - 10 * df['Elevation (km)']

print(df)
# Out:
#    Elevation (km)  Temperature (°C)
# 0               0                20
# 1               1                10
# 2               2                 0
# 3               3               -10
# 4               4               -20
# 5               5               -30

# %% [markdown]
# - If the temperature is 5°C, what is the elevation?

# %%
# if temp = 20 - 10 * h then h = (20 - temp) / 10
temp = 5
print(f'h = {(20 - temp) / 10}')
# Out:
# h = 1.5

# %% [markdown]
# 3. Henry’s car used 10.5 gal to drive 230 mi. Find its gas mileage.

# %%
gal = 10.5
mi = 230

mileage = mi / gal

print(f"Gas mileage: {mileage:.2f} miles/gal")
# Out:
# Gas mileage: 21.90 miles/gal

# %% [markdown]
# 1. The model L = 4S gives the total number of legs that S
# sheep have. Using this model, we ﬁnd that 12 sheep have
# - L = __legs.

# %%
sheep = 12
legs = 4 * sheep
legs
# Out:
# 48

# %% [markdown]
# 2. Suppose gas costs $3.50 a gallon. We make a model for the
# cost C of buying x gallons of gas by writing the formula
# - C = __

# %%
df_c = pd.DataFrame({'gallon (qnt)': range(1, 11)})

df_c['cost'] = 3.59 * df_c['gallon (qnt)']

df_c
# Out:
#    gallon (qnt)   cost
# 0             1   3.59
# 1             2   7.18
# 2             3  10.77
# 3             4  14.36
# 4             5  17.95
# 5             6  21.54
# 6             7  25.13
# 7             8  28.72
# 8             9  32.31
# 9            10  35.90

# %% [markdown]
# 3. The sales tax T in a certain county is modeled by the formula
# T = 0.06x. Find the sales tax on an item whose price is $120

# %%
price = 120
tax = 0.06 * price

print(f'Sales tax is equal: {tax:.2f}')
# Out:
# Sales tax is equal: 7.20

# %% [markdown]
# 4. Mintonville School District residents pay a wage tax T that is
# modeled by the formula T = 0.005x . Find the wage tax paid
# by a resident who earns $62,000 per year.

# %%
year_wage = 62000
wage_tax = 0.005 * year_wage

print(f'Wage tax is equal: {wage_tax}')
# Out:
# Wage tax is equal: 310.0

# %% [markdown]
# 5. The distance d (in mi) driven by a car traveling at a speed of
# v miles per hour for t hours is given by `d = vt`
#
# - If the car is driven at 70 mi/h for 3.5 h, how far has it traveled?

# %%
v = 70
t = 3.5

d = v * t

print(f'the distance is equal: {d}')
# Out:
# the distance is equal: 245.0

# %% [markdown]
# **6.** The volume $V$ of a cylindrical can is modeled by the formula:
# $$V = \pi r^2 h$$
# where $r$ is the radius and $h$ is the height of the can. Find the volume of a can with radius $3\text{ in.}$ and height $5\text{ in.}$

# %%
import math

r = 3
h = 5 

v = math.pi * (r ** 2) * h
print(f'the volume is equal: {v:.2f}')
# Out:
# the volume is equal: 141.37
